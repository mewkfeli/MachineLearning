# %% [markdown]
# ## 1. Подключение библиотек

# %%
pip install pymorphy3
# Out:
# Requirement already satisfied: pymorphy3 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (2.0.3)
# Requirement already satisfied: dawg2-python>=0.8.0 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from pymorphy3) (0.9.0)
# Requirement already satisfied: pymorphy3-dicts-ru in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from pymorphy3) (2.4.417150.4580142)
# Requirement already satisfied: setuptools>=68.2.2 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from pymorphy3) (80.0.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import string
import re
import nltk
import pymorphy3

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ROG\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ROG\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df_one =pd.read_csv("habr_parsing.csv")
df_two =pd.read_csv("json_dataset.csv")
df_three =pd.read_csv("PDF_dataset.csv")

# %%
df_two = df_two.drop(columns=['Unnamed: 0'])
df_three = df_three.drop(columns=['Unnamed: 0'])

# %%
df_one.columns = ['title', 'nameCompany', 'description', 'rating', 'field', 'date', 'textpub', 'views']
df_one.head()
# Out:
#                                                title         nameCompany  \
# 0  SSTI в Python под микроскопом: разбираем Pytho...             BI.ZONE
# 1                Противовирусная жевательная резинка  ua-hosting.company
# 2  Keycloak: как упростить аутентификацию и не со...           Clevertec
# 3  Из чего сделаны GPU от Т1 Облако? Фотообзор и ...          Холдинг Т1
# 4  Фундаментальные науки и ИТ: создание исследова...             Инферит
#
#                                         description  rating  \
# 0                                          Компания   76.41
# 1     Хостинг-провайдер: серверы в NL до 300 Гбит/с  169.07
# 2  Цифровые решения для бизнеса | финтех, логистика   59.14
# 3                        Многопрофильный ИТ-холдинг  125.41
# 4                                          Компания  229.82
#
#                                                field        date  \
# 0  Программное обеспечение, Веб-сервисы, Информац...  2025-04-09
# 1  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-09
# 2  Программное обеспечение, Мобильные технологии,...  2025-04-09
# 3  Программное обеспечение, Аппаратное обеспечени...  2025-04-09
# 4    Программное обеспечение, Аппаратное обеспечение  2025-04-09
#
#                                              textpub  views
# 0  Привет, Хабр! Меня зовут Сергей Арефьев. Я спе...    NaN
# 1    Пандемия, последствия которой до сих пор наб...    NaN
# 2  Привет! Я Диана, системный аналитик в Cleverte...    NaN
# 3  Привет, Хабр. На связи команда Т1 Облако. Если...    NaN
# 4  Развитие информационных технологий — от первых...    NaN

# %%
df_two.columns = ['nameCompany', 'description', 'textpub', 'date', 'rating', 'views']
df_two.head()
# Out:
#               nameCompany                                        description  \
# 0  Cybersport.Metaratings    Киберспортивное медиа и аналитическая платформа
# 1         ESforce Holding  Крупнейший холдинг в сфере киберспорта и игров...
# 2         ESforce Holding  Крупнейший холдинг в сфере киберспорта и игров...
# 3         ESforce Holding  Крупнейший холдинг в сфере киберспорта и игров...
# 4         ESforce Holding  Крупнейший холдинг в сфере киберспорта и игров...
#
#                                              textpub             date  rating  \
# 0  7 декабря состоялась церемония награждения лау...  8 декабря 09:30     6.0
# 1  7 декабря состоялась церемония награждения лау...  8 декабря 09:30     6.0
# 2  Из совместного исследования издателя компьютер...    29 июля 13:50    12.0
# 3  По статистике The Esports Observer за I полови...     9 июля 09:33    18.0
# 4  Компании SuperData Research и PayPal провели с...  11 апреля 12:43    11.0
#
#    views
# 0   2300
# 1   2300
# 2   2800
# 3   6200
# 4  10000

# %%
df_three.columns = ['nameCompany', 'rating', 'date', 'description', 'textpub']
df_three.head()
# Out:
#                   nameCompany  rating        date  \
# 0               red_mad_robot  117.94  2025-03-21
# 1  Технократия @technokratiya    4.40         NaN
# 2                     Cloud4Y   71.07  2025-03-21
# 3                      Kaiten   87.20  2025-03-27
# 4                     Cloud4Y   71.07  2025-03-21
#
#                                        description  \
# 0     №1 в разработке цифровых решений для бизнеса
# 1                                      ИТ-Компания
# 2              #1 Корпоративный облачный провайдер
# 3  Российский сервис для совместной работы команд.
# 4              #1 Корпоративный облачный провайдер
#
#                                              textpub
# 0  117.94\nРейтинг\nred_mad_robot\n№1 в разработк...
# 1  Еще до начала MWC в Барселоне было очевидно, ч...
# 2  71.07\nРейтинг\nCloud4Y\n#1 Корпоративный обла...
# 3  87.2\nРейтинг\nKaiten\nРоссийский сервис для с...
# 4  71.07\nРейтинг\nCloud4Y\n#1 Корпоративный обла...

# %%
df = pd.concat([df_one, df_two, df_three])
df = df.reset_index(drop=True)

# %%
df.head()
# Out:
#                                                title         nameCompany  \
# 0  SSTI в Python под микроскопом: разбираем Pytho...             BI.ZONE
# 1                Противовирусная жевательная резинка  ua-hosting.company
# 2  Keycloak: как упростить аутентификацию и не со...           Clevertec
# 3  Из чего сделаны GPU от Т1 Облако? Фотообзор и ...          Холдинг Т1
# 4  Фундаментальные науки и ИТ: создание исследова...             Инферит
#
#                                         description  rating  \
# 0                                          Компания   76.41
# 1     Хостинг-провайдер: серверы в NL до 300 Гбит/с  169.07
# 2  Цифровые решения для бизнеса | финтех, логистика   59.14
# 3                        Многопрофильный ИТ-холдинг  125.41
# 4                                          Компания  229.82
#
#                                                field        date  \
# 0  Программное обеспечение, Веб-сервисы, Информац...  2025-04-09
# 1  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-09
# 2  Программное обеспечение, Мобильные технологии,...  2025-04-09
# 3  Программное обеспечение, Аппаратное обеспечени...  2025-04-09
# 4    Программное обеспечение, Аппаратное обеспечение  2025-04-09
#
#                                              textpub  views
# 0  Привет, Хабр! Меня зовут Сергей Арефьев. Я спе...    NaN
# 1    Пандемия, последствия которой до сих пор наб...    NaN
# 2  Привет! Я Диана, системный аналитик в Cleverte...    NaN
# 3  Привет, Хабр. На связи команда Т1 Облако. Если...    NaN
# 4  Развитие информационных технологий — от первых...    NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1227 entries, 0 to 1226
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        90 non-null     object
#  1   nameCompany  1225 non-null   object
#  2   description  1225 non-null   object
#  3   rating       1227 non-null   float64
#  4   field        89 non-null     object
#  5   date         1224 non-null   object
#  6   textpub      1227 non-null   object
#  7   views        1112 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 76.8+ KB

# %%
df = df.drop('views', axis=1)

# %%
df.head()
# Out:
#                                                title         nameCompany  \
# 0  SSTI в Python под микроскопом: разбираем Pytho...             BI.ZONE
# 1                Противовирусная жевательная резинка  ua-hosting.company
# 2  Keycloak: как упростить аутентификацию и не со...           Clevertec
# 3  Из чего сделаны GPU от Т1 Облако? Фотообзор и ...          Холдинг Т1
# 4  Фундаментальные науки и ИТ: создание исследова...             Инферит
#
#                                         description  rating  \
# 0                                          Компания   76.41
# 1     Хостинг-провайдер: серверы в NL до 300 Гбит/с  169.07
# 2  Цифровые решения для бизнеса | финтех, логистика   59.14
# 3                        Многопрофильный ИТ-холдинг  125.41
# 4                                          Компания  229.82
#
#                                                field        date  \
# 0  Программное обеспечение, Веб-сервисы, Информац...  2025-04-09
# 1  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-09
# 2  Программное обеспечение, Мобильные технологии,...  2025-04-09
# 3  Программное обеспечение, Аппаратное обеспечени...  2025-04-09
# 4    Программное обеспечение, Аппаратное обеспечение  2025-04-09
#
#                                              textpub
# 0  Привет, Хабр! Меня зовут Сергей Арефьев. Я спе...
# 1    Пандемия, последствия которой до сих пор наб...
# 2  Привет! Я Диана, системный аналитик в Cleverte...
# 3  Привет, Хабр. На связи команда Т1 Облако. Если...
# 4  Развитие информационных технологий — от первых...

# %% [markdown]
# ## 2. Предварительная обработка данных

# %% [markdown]
# 1. Перевод всех букв в тексте в нижний регистр
# 2. Удаление знаков препинания
# 3. Токенизация по словам
# 4. Удаление стоп слов
# 5. Стемминг (приведение слов к нормальной форме)
# 6. Лемматизация

# %%
def remove_punctuation(text): 
    return "".join([ch if ch not in string.punctuation else ' ' for ch in text])

def remove_numbers(text): 
    return ''.join([i if not i.isdigit() else ' ' for i in text])

def remove_multiple_spaces(text): 
    return re.sub(r'\s+', ' ', text, flags=re.I)

st = '❯\xa0—«»'
def remove_othersymbol(text):
    return ''.join([ch if ch not in st else ' ' for ch in text])

# %%
df['text_new'] = [remove_multiple_spaces(remove_numbers(remove_othersymbol(remove_punctuation(text.lower())))) for text in df['textpub']]

# %%
df.head()
# Out:
#                                                title         nameCompany  \
# 0  SSTI в Python под микроскопом: разбираем Pytho...             BI.ZONE
# 1                Противовирусная жевательная резинка  ua-hosting.company
# 2  Keycloak: как упростить аутентификацию и не со...           Clevertec
# 3  Из чего сделаны GPU от Т1 Облако? Фотообзор и ...          Холдинг Т1
# 4  Фундаментальные науки и ИТ: создание исследова...             Инферит
#
#                                         description  rating  \
# 0                                          Компания   76.41
# 1     Хостинг-провайдер: серверы в NL до 300 Гбит/с  169.07
# 2  Цифровые решения для бизнеса | финтех, логистика   59.14
# 3                        Многопрофильный ИТ-холдинг  125.41
# 4                                          Компания  229.82
#
#                                                field        date  \
# 0  Программное обеспечение, Веб-сервисы, Информац...  2025-04-09
# 1  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-09
# 2  Программное обеспечение, Мобильные технологии,...  2025-04-09
# 3  Программное обеспечение, Аппаратное обеспечени...  2025-04-09
# 4    Программное обеспечение, Аппаратное обеспечение  2025-04-09
#
#                                              textpub  \
# 0  Привет, Хабр! Меня зовут Сергей Арефьев. Я спе...
# 1    Пандемия, последствия которой до сих пор наб...
# 2  Привет! Я Диана, системный аналитик в Cleverte...
# 3  Привет, Хабр. На связи команда Т1 Облако. Если...
# 4  Развитие информационных технологий — от первых...
#
#                                             text_new
# 0  привет хабр меня зовут сергей арефьев я специа...
# 1   пандемия последствия которой до сих пор наблю...
# 2  привет я диана системный аналитик в clevertec ...
# 3  привет хабр на связи команда т облако если вы ...
# 4  развитие информационных технологий от первых а...

# %%
russian_stopwords = stopwords.words("russian") 
russian_stopwords
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
russian_stopwords.extend(['т.д.', 'т', 'д', 'это','который', 'которая', 'с','своём','всем','наш', 'свой', 'ещё', "еще", "также", "так же", "всякий"])

# %%
def tokenize_text(text):
    t = word_tokenize(text)
    tokens = [token for token in t if token not in russian_stopwords and not re.search(r'[a-zA-Z]', token)]
    text = " ".join(tokens)
    return text

# %%
df['tokenize_texts'] = [tokenize_text(text) for text in df['text_new']]

# %%
stemmer = SnowballStemmer("russian")

stem_list = []
for text in (df['tokenize_texts']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = stemmer.stem(word)
            res.append(p)
        text = " ".join(res)
        stem_list.append(text)
    except Exception as e:
        print(e)
        
df['text_stem'] = stem_list

# %%
morph = pymorphy3.MorphAnalyzer(lang='ru')

# %%
# %%time
lemm_texts_list = []
for text in (df['tokenize_texts']):
    try:
        tokens = word_tokenize(text)
        res = list()
        for word in tokens:
            p = morph.parse(word)[0]
            res.append(p.normal_form)
        text = " ".join(res)
        lemm_texts_list.append(text)
    except Exception as e:
        print(e)
    
df['text_lemm'] = lemm_texts_list
# Out:
# CPU times: total: 1min 42s
# Wall time: 1min 42s

# %%
df['text_lemm'] = [tokenize_text(text) for text in df['text_lemm']]

# %% [markdown]
# # Облако слов

# %%
pip install WordCloud
# Out:
# Requirement already satisfied: WordCloud in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (11.2.1)
# Requirement already satisfied: matplotlib in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from WordCloud) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rog\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rog\appdata\local\programs\python\python312\lib\site-packages (from matplotlib->WordCloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rog\appdata\roaming\python\python312\site-packages (from matplotlib->WordCloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rog\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib->WordCloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Получение текстовой строки из списка слов
def str_corpus(corpus):
    str_corpus = ''
    for i in corpus:
        str_corpus += ' ' + i
    str_corpus = str_corpus.strip()
    return str_corpus

# Получение списка всех слов в корпусе
def get_corpus(data):
    corpus = []
    for phrase in data:
        for word in phrase.split():
            corpus.append(word)
    return corpus

# Получение облака слов
def get_wordCloud(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(str_corpus(corpus))
    return wordCloud

# %%
corpus = get_corpus(df['textpub'].values)
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
corpus = get_corpus(df['text_lemm'].values)
procWordCloud = get_wordCloud(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
# Получение облака слов
def get_wordCloud2(corpus):
    wordCloud = WordCloud(background_color='white',
                              stopwords=STOPWORDS,
                              width=3000,
                              height=2500,
                              max_words=200,
                              random_state=42
                         ).generate(corpus)
    return wordCloud

# %%
corpus = df['text_lemm'][0]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %%
corpus = df['text_lemm'][2]
procWordCloud = get_wordCloud2(corpus)

fig = plt.figure(figsize=(20, 8))
plt.subplot(1, 2, 1)
plt.imshow(procWordCloud)
plt.axis('off')
plt.subplot(1, 2, 1)
# Out:
# <Axes: >

# %% [markdown]
# # Векторизация текстовых данных

# %% [markdown]
# ### Bag of words

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
df['text_lemm'][0]
# Out:
# 'привет хабра звать сергей арефьев специалист отдел анализ защищённость приложение компания статья хотеть подробно раскрыть тема контекст сразу оговориться новый ресерч вектор лишь взять известный посмотреть почему работать полный понимание вопрос рассмотреть импакт атаковать мочь получить использовать пять самый популярный шаблонизатор кроме немного углубиться работа известный поделиться опыт вариант улучшение мочь полезный тестирование несколько слово шаблонизаторахначнуть базовый шаблонизатор применяться встретить шаблонизатор инструмент динамический генерация текстовый данные основа заранее задать шаблон частый встретить веб приложение использоваться рендеринг страница сервер последний несколько год концепция стать менее популярный уступить место клиентский рендеринг формироваться непосредственно браузер помощь фреймворк шаблонизатор прежний применять самый разный задача лишь некоторый генерация автоматический рассылка генерация конфигурационный файл генерация отчёт ⚠ опыт шаблонизатор частый использоваться рассылка пример применение шаблонизатор слишком специфичный встречаться большой количество приложение шаблонизатор живой поэтому считать уязвимость вымереть вид мочь обнаружить рамка багбаунтить время проект пентест прежде углубляться давать абстрагироваться секрет самый больший угроза создать уязвимость удалённый исполнение код шаблонизатор капот странно использовать рассмотреть мочь выполнить команда помощь язык общий пример иначе требовать загрузка дополнительный модуль вызвать команда мочь использовать например модуль любой конечный итог обращаться интересный факт капот использовать вариант использование загрузка библиотека помощь подгрузить вызвать команда выполнить нужно получить доступ модуль использовать модуль подкапотный код стоить держать голова давать вернуться заключаться уязвимость шаблонизатор обрабатывать управлять конструкция тег часто мочь содержать выражение выполнять контекст шаблон некоторый случай выражение мочь включать код случай код разобрать выполнить шаблонизатор уязвимость возникать злоумышленник получать возможность внедрить дать шаблон обработать шаблонизатор например произойти разработчик решить передавать дать контекст просто добавлять помощь конкатенация шаблон случай злоумышленник внедрить управлять конструкция шаблон впоследствии обработать шаблонизатор теория позволить выполнить произвольный код перейти конкретный пример самый популярный шаблонизаторначнуть популярный шаблонизатор многие знать проверка уязвимость использовать тег ответ получить значит ввод обработать часть шаблон успешно выполнить делать далёкий рассмотреть ранее нужно получить доступ модуль помочь выполнить код контекст незадача иметь управлять конструкция позволять выполнять произвольный код взглянуть документация становиться понятно наиболее подходящий конструкция атаковать следующий дать конструкция позволять работать простой тип данные выполнять математический логический операция обращаться объявить переменный свойство метод доступный контекст шаблон значит доступный контекст шаблон умолчание запускать шаблон песочница иметь ограниченный область видимость память означать смочь получить доступ переменный явно объявить шаблон передать контекст глобальный переменный язык например получить доступ желаемый модуль выполнить произвольный код существовать несколько метод давать разбираться использование работа заметить интересный особенность попытаться обратиться необъявленный переменный приложение упасть рендеринг место конструкция просто подставить пустой строка сделать удобство разработка приложение реализоваться помощь класс обращение необъявленный переменный присваиваться значение объект использовать выход глобальный область видимость обращаться конструктор класс позволять выйти предел текущий область затем использовать атрибут представлять словарь глобальный переменный функция оказаться глобальный область видимость мочь получить доступ атрибут содержать ссылка встроить функция класс исключение благодаря использоват ...

# %%
vectorizer = CountVectorizer()
vectorizer.fit(df['text_lemm'])
# Out:
# CountVectorizer()

# %%
print(vectorizer.vocabulary_)
# Out:
# {'привет': 35278, 'хабра': 50219, 'звать': 13874, 'сергей': 41864, 'арефьев': 1427, 'специалист': 44034, 'отдел': 28884, 'анализ': 1001, 'защищённость': 13848, 'приложение': 35569, 'компания': 17712, 'статья': 44593, 'хотеть': 50788, 'подробно': 32594, 'раскрыть': 38708, 'тема': 46174, 'контекст': 18014, 'сразу': 44315, 'оговориться': 27506, 'новый': 26423, 'ресерч': 39769, 'вектор': 4582, 'лишь': 20164, 'взять': 5016, 'известный': 14486, 'посмотреть': 34103, 'почему': 34497, 'работать': 37743, 'полный': 33289, 'понимание': 33652, 'вопрос': 5987, 'рассмотреть': 38917, 'импакт': 14841, 'атаковать': 1691, 'мочь': 22963, 'получить': 33456, 'использовать': 15594, 'пять': 37714, 'самый': 40984, 'популярный': 33823, 'шаблонизатор': 51947, 'кроме': 18940, 'немного': 25302, 'углубиться': 47939, 'работа': 37731, 'поделиться': 32271, 'опыт': 28321, 'вариант': 4324, 'улучшение': 48306, 'полезный': 33142, 'тестирование': 46400, 'несколько': 25838, 'слово': 42862, 'шаблонизаторахначнуть': 51948, 'базовый': 1991, 'применяться': 35611, 'встретить': 6496, 'инструмент': 15154, 'динамический': 10407, 'генерация': 7814, 'текстовый': 46060, 'данные': 9244, 'основа': 28591, 'заранее': 13371, 'задать': 12505, 'шаблон': 51944, 'частый': 51391, 'веб': 4506, 'использоваться': 15596, 'рендеринг': 39674, 'страница': 44938, 'сервер': 41835, 'последний': 34061, 'год': 8357, 'концепция': 18157, 'стать': 44588, 'менее': 21604, 'уступить': 48867, 'место': 21704, 'клиентский': 17075, 'формироваться': 49802, 'непосредственно': 25570, 'браузер': 3612, 'помощь': 33603, 'фреймворк': 50001, 'прежний': 34991, 'применять': 35610, 'разный': 38340, 'задача': 12507, 'некоторый': 25204, 'автоматический': 248, 'рассылка': 38967, 'конфигурационный': 18116, 'файл': 49157, 'отчёт': 29498, 'пример': 35612, 'применение': 35599, 'слишком': 42842, 'специфичный': 44053, 'встречаться': 6502, 'большой': 3442, 'количество': 17416, 'живой': 11984, 'поэтому': 34582, 'считать': 45598, 'уязвимость': 49118, 'вымереть': 6944, 'вид': 5034, 'обнаружить': 26980, 'рамка': 38579, 'багбаунтить': 1953, 'время': 6322, 'проект': 36383, 'пентест': 30363, 'прежде': 34988, 'углубляться': 47942, 'давать': 9138, 'абстрагироваться': 61, 'секрет': 41680, 'больший': 3440, 'угроза': 47990, 'создать': 43449, 'удалённый': 48012, 'исполнение': 15572, 'код': 17290, 'капот': 16183, 'странно': 44946, 'выполнить': 7042, 'команда': 17542, 'язык': 53674, 'общий': 27321, 'иначе': 14902, 'требовать': 47135, 'загрузка': 12474, 'дополнительный': 11040, 'модуль': 22599, 'вызвать': 6829, 'например': 24048, 'любой': 20518, 'конечный': 17874, 'итог': 15768, 'обращаться': 27141, 'интересный': 15224, 'факт': 49182, 'использование': 15589, 'библиотека': 2908, 'подгрузить': 32232, 'нужно': 26612, 'доступ': 11174, 'подкапотный': 32325, 'стоить': 44805, 'держать': 9909, 'голова': 8405, 'вернуться': 4706, 'заключаться': 12739, 'обрабатывать': 27091, 'управлять': 48572, 'конструкция': 17983, 'тег': 46032, 'часто': 51385, 'содержать': 43408, 'выражение': 7090, 'выполнять': 7045, 'случай': 42931, 'включать': 5393, 'разобрать': 38347, 'возникать': 5803, 'злоумышленник': 14073, 'получать': 33451, 'возможность': 5784, 'внедрить': 5541, 'дать': 9308, 'обработать': 27094, 'произойти': 36482, 'разработчик': 38403, 'решить': 39947, 'передавать': 30531, 'просто': 36935, 'добавлять': 10614, 'конкатенация': 17879, 'впоследствии': 6248, 'теория': 46238, 'позволить': 32895, 'произвольный': 36476, 'перейти': 30636, 'конкретный': 17888, 'шаблонизаторначнуть': 51949, 'многие': 22406, 'знать': 14125, 'проверка': 36113, 'ответ': 28806, 'значит': 14137, 'ввод': 4438, 'часть': 51392, 'успешно': 48780, 'делать': 9708, 'далёкий': 9218, 'ранее': 38598, 'помочь': 33597, 'незадача': 24946, 'иметь': 14809, 'позволять': 32896, 'взглянуть': 4948, 'документация': 10845, 'становиться': 44488, 'понятно': 33685, 'наиболее': 23694, 'подходящий': 32774, 'следующий': 42789, 'простой': 36939, 'тип': 46599, 'математический': 21170, 'логический': 20222, 'операция': 28 ...

# %%
vectorizer = CountVectorizer(analyzer='word', stop_words=russian_stopwords, ngram_range=(1, 3), min_df=2)
count_matrix = vectorizer.fit_transform(df['text_lemm'])

# %%
count_matrix.shape
# Out:
# (1227, 256934)

# %%
vectorizer.get_feature_names_out()[45000:46000]
# Out:
# array(['добродушно хохотнуть', 'добродушно хохотнуть видеть',
#        'добродушный', 'добродушный слегка',
#        'добродушный слегка располнеть', 'доброжелатель',
#        'доброжелательность', 'доброжелательность поверх',
#        'доброжелательность поверх плохо', 'доброжелательный',
#        'добропорядочный', 'добропорядочный гражданин', 'добросовестно',
#        'добросовестно пройти', 'добросовестный', 'добросовестный думать',
#        'добросовестный думать марс', 'доброта', 'добротно', 'добротность',
#        'добротность пароль', 'добротность пароль декоративный',
#        'добротный', 'добрый', 'добрый вечер', 'добрый викинг',
#        'добрый викинг притягивать', 'добрый воля', 'добрый временами',
#        'добрый временами река', 'добрый время', 'добрый время сравнение',
#        'добрый время сутки', 'добрый день', 'добрый день первый',
#        'добрый друг', 'добрый друг прекрасный', 'добрый дядя',
#        'добрый намерение', 'добрый намерение подобный', 'добрый половина',
#        'добрый путь', 'добрый сказка', 'добрый сказка сказка',
#        'добрый традиция', 'добрый традиция публикация', 'добрый утро',
#        'добрый утро добрый', 'добрый утром', 'добрый химия',
#        'добрый химия создавать', 'добрый человек', 'добывание',
#        'добывать', 'добываться', 'добыть', 'добыча', 'добыча мочь',
#        'добыча нефть', 'доведение', 'доведение ум', 'довезти',
#        'доверенность', 'доверенный', 'доверенный лицо',
#        'доверенный среда', 'доверенный среда контрагент', 'доверие',
#        'доверие агент', 'доверие агент механизм', 'доверие весь',
#        'доверие друг', 'доверие друг друг', 'доверие идти',
#        'доверие менеджмент', 'доверие повышаться',
#        'доверие повышаться мочь', 'доверие проект', 'доверие сотрудник',
#        'доверие сторона', 'доверие уважение', 'доверие формировать',
#        'доверие являться', 'доверительный', 'доверительный отношение',
#        'доверить', 'доверить должность',
#        'доверить должность региональный', 'доверить представлять',
#        'доверить представлять интерес', 'довериться',
#        'довериться инстинкт', 'довериться инстинкт первоочередной',
#        'доверчивый', 'довершать', 'доверять', 'доверять встроить',
#        'доверять встроить защита', 'доверять город',
#        'доверять город зато', 'доверять дать', 'доверять дать оружие',
#        'доверять друг', 'доверять друг друг', 'доверять мнение',
#        'доверять мочь', 'доверять перестать',
#        'доверять перестать выбросить', 'доверять полагаться',
#        'доверять полагаться знание', 'доверять поставщик',
#        'доверять разумеется', 'доверять разумеется использовать',
#        'доверять человек', 'доверяться', 'довесок', 'довести',
#        'довести автоматизм', 'довести её', 'довести капитальный',
#        'довести капитальный сооружение', 'довести конец',
#        'довести проект', 'довести результат', 'довести ум',
#        'довести финал', 'довестись', 'довестись присоединиться',
#        'довестись присоединиться команда', 'довлеть', 'довлеть жёлтый',
#        'довлеть жёлтый красный', 'довод', 'довод рассудок',
#        'довод рассудок почему', 'доводить', 'доводить дело',
#        'доводить дело именно', 'доводить совершенство', 'доводить ум',
#        'доводиться', 'доводка', 'довольно', 'довольно агент',
#        'довольно агент личность', 'довольно агрессивный',
#        'довольно активный', 'довольно безобидный',
#        'довольно безобидный развлечение', 'довольно безразличный',
#        'довольно болезненный', 'довольно больший', 'довольно большой',
#        'довольно большой красный', 'довольно большой проблема',
#        'довольно большой существующий', 'довольно быстро',
#        'довольно быстро выясниться', 'довольно быстро найти',
#        'довольно быстро прийти', 'довольно быстро скопление',
#        'довольно быстро удаться', 'довольно быстрый', 'довольно важный',
#        'довольно внушительный', 'довольно время', 'довольно высокий',
#        'довольно грубый', 'довольно давно', 'довольно давно работать',
#        'довольно далеко', 'довольно далеко связать', 'довольно длинный',
#        'довольно длительный', 'довольно долгий', 'довольно долгий время',
#        'довольно долго', 'довольно долго автомобильный',
#        'довольно дорога', 'довольно дорого', 'довольно дорого ой',
#        'довольно дорогой', 'довольно жестоко', 'довольно жестоко твой',
#        'довольно жёстко', 'довольно забавно',
#        'довольно забавно веселиться', 'довольно забавный',
#        'довольно заметный', 'довольно затратный', 'довольно известный',
#        'довольно интересный', 'довольно компактный', 'довольно крупный',
#        'довольно крутой', 'довольно легко', 'довольно лёгкое',
#        'довольно мало', 'довольно массивный',
#        'довольно массивный электронный', 'довольно медленный',
#        'довольно место', 'довольно минималистичный', 'довольно молодой',
#        'довольно мощный', 'довольно мягкий', 'довольно народ',
#        'довольно необычно', 'довольно необычный', 'довольно неплохо',
#        'довольно неплохой', 'довольно неприятный', 'довольно низкий',
#        'довольно новый', 'довольно обширный', 'довольно общий',
#        'довольно объёмный', 'довольно ограничить', 'довольно опытный',
#        'довольно оскалиться', 'довольно оскалиться сразу',
#        'довольно острый', 'довольно откровенно', 'довольно очевидный',
#        'довольно очевидный сон', 'довольно плотно',
#        'довольно поверхностный', 'довольно подробно',
#        'довольно подробный', 'довольно пожилой', 'довольно поздно',
#        'довольно понятно', 'довольно понятно ребята',
#        'довольно популярный', 'довольно примитивный',
#        'довольно проблематично', 'довольно проблемный',
#        'довольно продвинуть', 'довольно прозрачный', 'довольно просто',
#        'довольно просто сделать', 'довольно простой',
#        'довольно простой использовать', 'довольно простой способ',
#        'довольно распространить', 'довольно редкий',
#        'довольно редкий увлечение', 'довольно редкий явление',
#        'довольно редко', 'довольно серьёзный', 'довольно сильно',
#        'довольно сильно поменяться', 'довольно сильный', 'довольно скоро',
#        'довольно скудный', 'довольно скучный', 'довольно сложно',
#        'довольно сложный', 'довольно сложный физический',
#        'довольно стандартный', 'довольно старый', 'довольно старый кой',
#        'довольно странно', 'довольно странный', 'довольно субъективный',
#        'довольно таки', 'довольно точно', 'довольно трудно',
#        'довольно тяжело', 'довольно тяжёлый', 'довольно удачный',
#        'довольно удобно', 'довольно удобный', 'довольно успешно',
#        'довольно устойчивый', 'довольно хороший', 'довольно часто',
#        'довольно часто встречаться', 'довольно часто значительный',
#        'довольно частый', 'довольно человек', 'довольно широкий',
#        'довольно широко', 'довольно эффективно', 'довольно ёмко',
#        'довольный', 'довольный вид', 'довольный вид сбыться',
#        'довольный возможность', 'довольный вообще',
#        'довольный вообще теория', 'довольный воспоминание',
#        'довольный воспоминание забытый', 'довольный жизнь',
#        'довольный итог', 'довольный качество', 'довольный клиент',
#        'довольный получиться', 'довольный приносить',
#        'довольный приносить деньга', 'довольный работа',
#        'довольный результат', 'довольный улыбка', 'довольный хотя',
#        'довольствоваться', 'довольствоваться ответ',
#        'довольствоваться путешествие',
#        'довольствоваться путешествие четыре', 'догадаться',
#        'догадаться интересно', 'догадаться название',
#        'догадаться огрызнуться', 'догадаться огрызнуться денис',
#        'догадаться помогать', 'догадаться помогать образ',
#        'догадаться понять', 'догадаться понять пояснить',
#        'догадаться почему', 'догадаться почему сексот',
#        'догадаться сделать', 'догадаться ход', 'догадаться ход дело',
#        'догадаться шахматы', 'догадаться шахматы пример', 'догадка',
#        'догадка блядь', 'догадка блядь знать', 'догадка макс',
#        'догадка макс родиться', 'догадываться', 'догадываться например',
#        'догадываться смысл', 'догадываться хотеть',
#        'догадываться хотеть ладный', 'догма', 'догнать', 'догнать дверь',
#        'догнать миг', 'догнать миг денис', 'догнать пахать',
#        'догнать пахать робот', 'договариваться', 'договариваться встреча',
#        'договариваться команда', 'договариваться москва',
#        'договариваться москва системный', 'договариваться неужели',
#        'договариваться неужели устройство', 'договариваться нормально',
#        'договариваться нормально приехать', 'договариваться рой',
#        'договариваться рой очень', 'договариваться сотрудничество',
#        'договор', 'договор абонент', 'договор абонент предусмотреть',
#        'договор аренда', 'договор арумов', 'договор арумов совет',
#        'договор должный', 'договор заказчик', 'договор клиент',
#        'договор комбат', 'договор комбат решить', 'договор компания',
#        'договор купля', 'договор купля продажа', 'договор макс',
#        'договор макс пугать', 'договор мочь', 'договор неразглашение',
#        'договор нужно', 'договор оператор', 'договор оператор участник',
#        'договор описать', 'договор описать немой', 'договор оплата',
#        'договор оферта', 'договор подписать', 'договор подряд',
#        'договор подумать', 'договор подумать макс', 'договор право',
#        'договор прислать', 'договор прописывать',
#        'договор прописывать условие', 'договор разработка',
#        'договор разработка сайт', 'договор сказать',
#        'договор сказать нужный', 'договор юрист', 'договорить',
#        'договорить первый', 'договорить первый случиться', 'договориться',
#        'договориться босс', 'договориться босс получить',
#        'договориться брать', 'договориться брать марс',
#        'договориться внести', 'договориться внести предоплата',
#        'договориться враг', 'договориться враг получить',
#        'договориться заказчик', 'договориться использовать',
#        'договориться использовать порт', 'договориться каждый',
#        'договориться клиент', 'договориться макс',
#        'договориться макс очень', 'договориться место',
#        'договориться партнёрство', 'договориться сразу',
#        'договориться считать', 'договориться человек', 'договорный',
#        'договорный отношение', 'договорённость', 'договорённость делать',
#        'договорённость оперативный', 'договорённость оперативный штаб',
#        'догонялки', 'догонять', 'догонять меланхолично',
#        'догонять меланхолично ответить', 'додайвиться',
#        'додайвиться появление', 'додайвиться появление тень', 'доделать',
#        'доделать задача', 'доделать поздний', 'доделка', 'доделывать',
#        'доделываться', 'додсон', 'додумать', 'додуматься',
#        'додуматься раздавить', 'додуматься раздавить счёт', 'додумывать',
#        'додый', 'додый пицца', 'доезжать', 'доесть', 'доехать',
#        'доехать изрядно', 'доехать изрядно потрепать', 'дожать',
#        'дождаться', 'дождаться вакцина', 'дождаться окончание',
#        'дождаться пока', 'дождаться пока бумажка', 'дождаться такси',
#        'дождаться такси затруднительный', 'дождик', 'дождливый',
#        'дождливый осенний', 'дождливый погода', 'дождь', 'дождь зелёный',
#        'дождь кстати', 'дождь кстати погода', 'дождь очень',
#        'дождь распасться', 'дождь распасться обязательно', 'доживать',
#        'дожидаться', 'дожидаться завершение', 'дожидаться ответ',
#        'дожидаться пока', 'дожидаться пока дать', 'дожидаться полный',
#        'дожидаться приглашение',
#        'дожидаться приглашение новообразовавшийся', 'дожимать', 'дожить',
#        'дожить момент', 'дожить рой', 'дожить рой хотя', 'доза',
#        'доза больший', 'доза лучевой', 'доза маленький', 'доза облучение',
#        'доза получить', 'доза порядок', 'доза составлять',
#        'доза транквилизатор', 'доза человек', 'доза человек умирать',
#        'доза яд', 'доза яд полтора', 'дозаправка', 'дозаряд', 'дозатор',
#        'дозваниваться', 'дозволить', 'дозволить правда',
#        'дозволить правда самец', 'дозволяться', 'дозвон', 'дозвониться',
#        'дозвониться слушать', 'дозвониться слушать извинить', 'дозиметр',
#        'дозиметрический', 'дозировать', 'дозировка', 'дозовый',
#        'доисторический', 'дойти', 'дойти время', 'дойти дверь',
#        'дойти дойти', 'дойти дойти пускай', 'дойти клиника',
#        'дойти клиника говорить', 'дойти конец', 'дойти место',
#        'дойти момент', 'дойти планка', 'дойти планка хотеть',
#        'дойти пока', 'дойти попасть', 'дойти последний', 'дойти примерно',
#        'дойти прогресс', 'дойти прогресс боксёрский', 'дойти пускай',
#        'дойти пускай спать', 'дойти сегодняшний',
#        'дойти сегодняшний жизнь', 'дойти смысл', 'дойти уровень', 'дойча',
#        'док', 'док станция', 'доказательный', 'доказательный база',
#        'доказательный медицина', 'доказательство',
#        'доказательство определить', 'доказательство определить ответ',
#        'доказательство причастность', 'доказательство хотеть',
#        'доказательство хотеть верить', 'доказательство эффективность',
#        'доказать', 'доказать ваш', 'доказать достойный',
#        'доказать достойный получить', 'доказать методика',
#        'доказать мочь', 'доказать навык', 'доказать навык мочь',
#        'доказать полезность', 'доказать простой',
#        'доказать простой биологический', 'доказать работать',
#        'доказать существование', 'доказать существование высокий',
#        'доказать хороший', 'доказать хороший решение',
#        'доказать экспертиза', 'доказать экспертиза совместный',
#        'доказать эффективность', 'доказывание', 'доказывать',
#        'доказывать верблюд', 'доказывать либо',
#        'доказывать либо находиться', 'доказываться', 'докапываться',
#        'докапываться стратегический',
#        'докапываться стратегический объект', 'докатиться', 'докдок',
#        'докер', 'докер образ', 'докинуть', 'докинуть идти',
#        'докинуть идти основной', 'доклад', 'доклад автор',
#        'доклад активация', 'доклад активация обмен', 'доклад александр',
#        'доклад александр рассказать', 'доклад алексей',
#        'доклад английский', 'доклад английский перевод', 'доклад андрей',
#        'доклад артём', 'доклад большинство', 'доклад валентина',
#        'доклад ведущий', 'доклад весь', 'доклад весь компания',
#        'доклад видео', 'доклад вместе', 'доклад второй',
#        'доклад выложить', 'доклад выступить', 'доклад глеб',
#        'доклад глеб построить', 'доклад год', 'доклад давать',
#        'доклад делать', 'доклад джон', 'доклад дизайн', 'доклад дмитрий',
#        'доклад добавить', 'доклад доклад', 'доклад доклад александр',
#        'доклад докладчик', 'доклад достаточно', 'доклад екатерина',
#        'доклад живой', 'доклад зал', 'доклад заявить', 'доклад звать',
#        'доклад иван', 'доклад игра', 'доклад игра нетворкинг',
#        'доклад идти', 'доклад интересно', 'доклад интересный',
#        'доклад йонатан', 'доклад йонатан поделиться', 'доклад касаться',
#        'доклад кейс', 'доклад компания', 'доклад конференция',
#        'доклад конференция май', 'доклад конференция рассказать',
#        'доклад круглый', 'доклад круглый стол', 'доклад крутой',
#        'доклад кстати', 'доклад купить', 'доклад методология',
#        'доклад минута', 'доклад митапа', 'доклад михаил', 'доклад многий',
#        'доклад многий конференция', 'доклад написать', 'доклад например',
#        'доклад немой', 'доклад несколько', 'доклад николай',
#        'доклад новый', 'доклад обратиться', 'доклад общение',
#        'доклад олег', 'доклад ольга', 'доклад основать',
#        'доклад основать опыт', 'доклад особо', 'доклад очень',
#        'доклад пара', 'доклад первый', 'доклад писать',
#        'доклад поговорить', 'доклад поговорить жить', 'доклад поделиться',
#        'доклад подробно', 'доклад пойти', 'доклад полезный',
#        'доклад получаться', 'доклад полчаса', 'доклад понять',
#        'доклад попасть', 'доклад посвятить', 'доклад посвятить многие',
#        'доклад почему', 'доклад появиться', 'доклад представитель',
#        'доклад представить', 'доклад предыдущий', 'доклад презентация',
#        'доклад принять', 'доклад приходить', 'доклад программа',
#        'доклад просто', 'доклад работа', 'доклад работать',
#        'доклад разный', 'доклад разобрать', 'доклад разработчик',
#        'доклад рассказать', 'доклад рассказать заложить',
#        'доклад рассказать использовать', 'доклад рассказать сложность',
#        'доклад рассказывать', 'доклад рассмотреть', 'доклад рекрутер',
#        'доклад рекрутер собрать', 'доклад решить', 'доклад сайт',
#        'доклад самый', 'доклад саша', 'доклад свободный',
#        'доклад свободный общение', 'доклад сделать', 'доклад серебряный',
#        'доклад серебряный пуля', 'доклад сидеть', 'доклад смочь',
#        'доклад советовать', 'доклад состояние', 'доклад специалист',
#        'доклад спикер', 'доклад спикер показать', 'доклад стенд',
#        'доклад стенд хороший', 'доклад страница', 'доклад текстовый',
#        'доклад тема', 'доклад увидеть', 'доклад узнать',
#        'доклад упомянуть', 'доклад управление',
#        'доклад управление знание', 'доклад участник', 'доклад учить',
#        'доклад учёный', 'доклад хотеть', 'доклад час', 'доклад человек',
#        'докладчик', 'докладчик весь', 'докладчик время',
#        'докладчик выйти', 'докладчик говорить', 'докладчик доклад',
#        'докладчик компания', 'докладывать', 'докладывать тайный',
#        'докладывать тайный повелитель', 'доковидный', 'доковидный время',
#        'докомпьютерный', 'докомпьютерный эра', 'докомпьютерный эра плохо',
#        'докопаться', 'докопаться суть', 'докопаться суть выяснить',
#        'докрутить', 'докручивания', 'доктор', 'доктор биологический',
#        'доктор биологический наука', 'доктор вести', 'доктор впору',
#        'доктор впору ваш', 'доктор ева', 'доктор ева шульц',
#        'доктор запустить', 'доктор запустить программа', 'доктор лишь',
#        'доктор лишь добродушно', 'доктор медицина', 'доктор наука',
#        'доктор нормально', 'доктор нормально зевнуть', 'доктор отто',
#        'доктор отто шульц', 'доктор посмотреть', 'доктор посмотреть лог',
#        'доктор прописать', 'доктор самый', 'доктор слегка',
#        'доктор слегка ошарашить', 'доктор чип', 'доктор чип обычно',
#        'докторский', 'докторский диссертация', 'докторский степень',
#        'докторский степень год', 'документ', 'документ автоматически',
#        'документ ассоциация', 'документ ассоциация вычислительный',
#        'документ внутри', 'документ возможность', 'документ год',
#        'документ далее', 'документ данный', 'документ договор',
#        'документ должный', 'документ знакомый', 'документ имя',
#        'документ иной', 'документ интуитивно',
#        'документ интуитивно понятный', 'документ использовать',
#        'документ каждый', 'документ компания', 'документ критерий',
#        'документ кроме', 'документ ладный', 'документ ладный пора',
#        'документ либо', 'документ мочь', 'документ мочь получить',
#        'документ написать', 'документ например', 'документ никакой',
#        'документ новый', 'документ нормально', 'документ нужно',
#        'документ нужный', 'документ образование', 'документ описание',
#        'документ отправить', 'документ отправляться', 'документ отчаяние',
#        'документ отчаяние называть', 'документ отчёт', 'документ первый',
#        'документ подготовить', 'документ подписать',
#        'документ подтверждать', 'документ позволять',
#        'документ получение', 'документ помогать', 'документ понимать',
#        'документ понимать крошечный', 'документ постановление',
#        'документ постановление минкомсвязи', 'документ предприятие',
#        'документ представлять', 'документ проблема', 'документ проект',
#        'документ просто', 'документ просто должный',
#        'документ просто расписаться', 'документ расход',
#        'документ расход якобы', 'документ реальный',
#        'документ регламентировать', 'документ решение',
#        'документ связаться', 'документ связаться никто',
#        'документ сделать', 'документ сей', 'документ сектор',
#        'документ сектор оптимизация', 'документ система',
#        'документ сказать', 'документ собрать',
#        'документ собрать проблема', 'документ соглашение',
#        'документ соглашение конфиденциальность', 'документ содержать',
#        'документ создать', 'документ сотрудник', 'документ стандарт',
#        'документ стоимость', 'документ сторона', 'документ текст',
#        'документ технический', 'документ технический задание',
#        'документ требоваться', 'документ удостоверять',
#        'документ удостоверять личность', 'документ указать',
#        'документ указывать', 'документ условие', 'документ федеральный',
#        'документ фиксировать', 'документ форма', 'документ формат',
#        'документ фстэк', 'документ хотя', 'документ число',
#        'документ электронный', 'документальный', 'документальный фильм',
#        'документация', 'документация библиотека', 'документация ваш',
#        'документация ведение', 'документация ведение база',
#        'документация вид', 'документация возможно',
#        'документация встроить', 'документация всё', 'документация делать',
#        'документация довольно', 'документация документация',
#        'документация должный', 'документация использование',
#        'документация использовать', 'документация код',
#        'документация кроме', 'документация модуль', 'документация мочь',
#        'документация написать', 'документация например',
#        'документация обычно', 'документация описание',
#        'документация очень', 'документация первый', 'документация писать',
#        'документация подробно', 'документация пока',
#        'документация получить', 'документация предоставлять',
#        'документация пример', 'документация продукт',
#        'документация проект', 'документация проектный',
#        'документация просто', 'документация работа',
#        'документация результат', 'документация решить',
#        'документация русский', 'документация сделать',
#        'документация сервис', 'документация снова',
#        'документация составлять', 'документация спецификация',
#        'документация список', 'документация ссылка',
#        'документация ссылка пример', 'документация стать',
#        'документация тема', 'документация тестирование',
#        'документация технический', 'документация указать',
#        'документация управление', 'документация утилит',
#        'документация утилит доступный', 'документация фреймворк',
#        'документация храниться', 'документация часто',
#        'документация язык', 'документирование', 'документирование работа',
#        'документированный', 'документировать',
#        'документировать результат', 'документировать результат работа',
#        'документный', 'документооборот', 'докупать', 'докупить',
#        'докурить', 'докучаев', 'долбануть', 'долбануть нормальный',
#        'долбануть нормальный надёжно', 'долбаный', 'долбаный балашиха',
#        'долбаный балашиха коляна', 'долбаный ботаник',
#        'долбаный ботаник пихать', 'долбаный контейнер',
#        'долбаный контейнер гермозон', 'долбаный контейнер серьёзно',
#        'долбаный отморозок', 'долбаный отморозок иметь',
#        'долбаный протокол', 'долбаный протокол пухлый', 'долбать',
#        'долбить', 'долг', 'долг буквально', 'долг вернуть',
#        'долг вернуть смерть', 'долг дать', 'долг дать валюта',
#        'долг деньга', 'долг доклад', 'долг доклад поговорить',
#        'долг кредит', 'долг первый', 'долг первый зарплата',
#        'долг придумать', 'долг придумать план', 'долг размер',
#        'долг размер млрд', 'долг родина', 'долг служба',
#        'долг служба нужно', 'долг технический', 'долгий',
#        'долгий возможно', 'долгий время', 'долгий время делать',
#        'долгий время работать', 'долгий год', 'долгий год вели',
#        'долгий год засилье', 'долгий год охранять',
#        'долгий год существование', 'долгий дискуссия'], dtype=object)

# %%
print(count_matrix)
# Out:
#   (0, 163606)	1
#   (0, 242915)	1
#   (0, 59791)	1
#   (0, 200765)	1
#   (0, 214944)	1
#   (0, 131316)	1
#   (0, 2423)	1
#   (0, 59655)	1
#   (0, 165075)	9
#   (0, 79987)	4
#   (0, 219810)	3
#   (0, 244508)	4
#   (0, 145544)	1
#   (0, 186334)	1
#   (0, 226871)	2
#   (0, 82568)	10
#   (0, 216888)	3
#   (0, 123964)	1
#   (0, 116609)	1
#   (0, 190973)	1
#   (0, 13598)	3
#   (0, 89566)	5
#   (0, 15985)	2
#   (0, 63998)	3
#   (0, 156658)	3
#   :	:
#   (1226, 60237)	1
#   (1226, 249641)	1
#   (1226, 163762)	1
#   (1226, 18966)	1
#   (1226, 4315)	1
#   (1226, 126002)	1
#   (1226, 93077)	1
#   (1226, 210392)	1
#   (1226, 73621)	1
#   (1226, 93604)	1
#   (1226, 200918)	1
#   (1226, 13334)	1
#   (1226, 126049)	1
#   (1226, 184579)	1
#   (1226, 1202)	1
#   (1226, 210391)	1
#   (1226, 73616)	1
#   (1226, 3407)	1
#   (1226, 188398)	1
#   (1226, 185493)	1
#   (1226, 222562)	1
#   (1226, 177916)	1
#   (1226, 126050)	1
#   (1226, 184933)	1
#   (1226, 54951)	1

# %% [markdown]
# ### TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf_vectorizer = TfidfVectorizer(max_df=0.8, max_features=10000,
                                 min_df=0.01, stop_words=russian_stopwords,
                                 ngram_range=(1,3))

# %%
# %%time
tfidf_matrix = tfidf_vectorizer.fit_transform(df['text_lemm'])
# Out:
# CPU times: total: 11.2 s
# Wall time: 11.2 s

# %%
tfidf_matrix.shape
# Out:
# (1227, 10000)

# %%
tfidf_vectorizer.get_feature_names_out()[:100]
# Out:
# array(['аббревиатура', 'абзац', 'абонент', 'абсолютно', 'абсолютный',
#        'абстрагироваться', 'абстрактный', 'абстракция', 'аварийный',
#        'авария', 'аватар', 'август', 'август год', 'авиакомпания',
#        'авить', 'авто', 'автобус', 'автомат', 'автоматизация',
#        'автоматизация тестирование', 'автоматизированный',
#        'автоматизировать', 'автоматически', 'автоматический',
#        'автомобиль', 'автомобильный', 'автономный', 'автопилот', 'автор',
#        'автор книга', 'автор компания', 'автор компания документ',
#        'автор песочница', 'авторизация', 'авторитет', 'авторитетный',
#        'авторский', 'автотест', 'ага', 'агент', 'агентство', 'агрегатор',
#        'агрегатор такси', 'агрегировать', 'агрессивный', 'агрессия', 'ад',
#        'адаптация', 'адаптер', 'адаптивный', 'адаптировать',
#        'адаптироваться', 'адекватно', 'адекватный', 'адепт', 'админ',
#        'административный', 'администратор', 'администрация',
#        'администрирование', 'админк', 'адрес', 'адресовать', 'аж', 'аз',
#        'азия', 'айти', 'айтишник', 'айфон', 'академический', 'академия',
#        'аккаунт', 'аккаунт войти', 'аккаунт войти регистрация',
#        'аккумулятор', 'аккуратно', 'аккуратный', 'аксессуар', 'акт',
#        'актив', 'активация', 'активировать', 'активироваться', 'активно',
#        'активно использовать', 'активно использоваться', 'активность',
#        'активный', 'актуально', 'актуальность', 'актуальный', 'актёр',
#        'акцент', 'акционер', 'акция', 'алан', 'алгоритм',
#        'алгоритм машинный', 'алгоритм машинный обучение',
#        'алгоритмический'], dtype=object)

# %%
print(tfidf_matrix)
# Out:
#   (0, 6438)	0.011221202814440808
#   (0, 9473)	0.008428590065415341
#   (0, 2357)	0.012999408822890742
#   (0, 7832)	0.013418996983914284
#   (0, 8341)	0.008331611682243919
#   (0, 5051)	0.01190621475826042
#   (0, 118)	0.009646203942997873
#   (0, 2349)	0.021699875719553213
#   (0, 6520)	0.06628922759286998
#   (0, 3062)	0.023142540608235666
#   (0, 8507)	0.021057851943841046
#   (0, 9549)	0.02538593884477921
#   (0, 5762)	0.012509554199064927
#   (0, 7306)	0.015938427740839433
#   (0, 8775)	0.015571903308815084
#   (0, 3153)	0.11976856636833264
#   (0, 8414)	0.022278554514811505
#   (0, 4458)	0.0051653131873018515
#   (0, 563)	0.049671893980401824
#   (0, 3457)	0.04340904133873748
#   (0, 661)	0.016492579923652564
#   (0, 2486)	0.02787071140940224
#   (0, 6135)	0.024488231555423116
#   (0, 6214)	0.006964381110609958
#   (0, 7072)	0.010235397639312856
#   :	:
#   (1226, 6748)	0.01983121115961201
#   (1226, 4151)	0.01983121115961201
#   (1226, 501)	0.020239508853406835
#   (1226, 73)	0.020239508853406835
#   (1226, 847)	0.020239508853406835
#   (1226, 4457)	0.020029985184917574
#   (1226, 9472)	0.01983121115961201
#   (1226, 3064)	0.020029985184917574
#   (1226, 2700)	0.020239508853406835
#   (1226, 9288)	0.01983121115961201
#   (1226, 7638)	0.020029985184917574
#   (1226, 31)	0.020029985184917574
#   (1226, 3068)	0.01983121115961201
#   (1226, 1800)	0.020029985184917574
#   (1226, 9250)	0.020239508853406835
#   (1226, 3216)	0.01983121115961201
#   (1226, 344)	0.01983121115961201
#   (1226, 3625)	0.020029985184917574
#   (1226, 7456)	0.020029985184917574
#   (1226, 4161)	0.01983121115961201
#   (1226, 6749)	0.01983121115961201
#   (1226, 4651)	0.020029985184917574
#   (1226, 4152)	0.020029985184917574
#   (1226, 9976)	0.020029985184917574
#   (1226, 6871)	0.10606706777134689

# %% [markdown]
# ## Кластеризация данных

# %% [markdown]
# ### K-means

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(tfidf_matrix)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Кол-во кластеров')
plt.show()
# Out:
#   File "c:\Users\ROG\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#                ^^^^^^^^^^^^^^^
#   File "c:\Users\ROG\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 548, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ROG\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1026, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#   File "c:\Users\ROG\AppData\Local\Programs\Python\Python312\Lib\subprocess.py", line 1538, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^

# %%
kmeans = KMeans(init='k-means++', n_clusters=8, n_init=10, random_state = 42)

# %%
kmeans.fit(tfidf_matrix)
# Out:
# KMeans(n_init=10, random_state=42)

# %%
pred=kmeans.fit_predict(tfidf_matrix)

# %%
df['cluster'] = pred
print(df['cluster'].value_counts())
sns.countplot(x='cluster', data=df)
plt.show()
# Out:
# cluster
# 4    361
# 3    260
# 6    240
# 5    118
# 7    110
# 1     65
# 0     60
# 2     13
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                                                title         nameCompany  \
# 0  SSTI в Python под микроскопом: разбираем Pytho...             BI.ZONE
# 1                Противовирусная жевательная резинка  ua-hosting.company
# 2  Keycloak: как упростить аутентификацию и не со...           Clevertec
# 3  Из чего сделаны GPU от Т1 Облако? Фотообзор и ...          Холдинг Т1
# 4  Фундаментальные науки и ИТ: создание исследова...             Инферит
#
#                                         description  rating  \
# 0                                          Компания   76.41
# 1     Хостинг-провайдер: серверы в NL до 300 Гбит/с  169.07
# 2  Цифровые решения для бизнеса | финтех, логистика   59.14
# 3                        Многопрофильный ИТ-холдинг  125.41
# 4                                          Компания  229.82
#
#                                                field        date  \
# 0  Программное обеспечение, Веб-сервисы, Информац...  2025-04-09
# 1  Аппаратное обеспечение, Связь и телекоммуникац...  2025-04-09
# 2  Программное обеспечение, Мобильные технологии,...  2025-04-09
# 3  Программное обеспечение, Аппаратное обеспечени...  2025-04-09
# 4    Программное обеспечение, Аппаратное обеспечение  2025-04-09
#
#                                              textpub  \
# 0  Привет, Хабр! Меня зовут Сергей Арефьев. Я спе...
# 1    Пандемия, последствия которой до сих пор наб...
# 2  Привет! Я Диана, системный аналитик в Cleverte...
# 3  Привет, Хабр. На связи команда Т1 Облако. Если...
# 4  Развитие информационных технологий — от первых...
#
#                                             text_new  \
# 0  привет хабр меня зовут сергей арефьев я специа...
# 1   пандемия последствия которой до сих пор наблю...
# 2  привет я диана системный аналитик в clevertec ...
# 3  привет хабр на связи команда т облако если вы ...
# 4  развитие информационных технологий от первых а...
#
#                                       tokenize_texts  \
# 0  привет хабр зовут сергей арефьев специалист от...
# 1  пандемия последствия которой сих пор наблюдают...
# 2  привет диана системный аналитик экс преподават...
# 3  привет хабр связи команда облако следите новос...
# 4  развитие информационных технологий первых алго...
#
#                                            text_stem  \
# 0  привет хабр зовут серг ареф специалист отдел а...
# 1  пандем последств котор сих пор наблюда всем ми...
# 2  привет диа системн аналитик экс преподавател с...
# 3  привет хабр связ команд облак след новост мир ...
# 4  развит информацион технолог перв алгоритм нейр...
#
#                                            text_lemm  cluster
# 0  привет хабра звать сергей арефьев специалист о...        3
# 1  пандемия последствие сей пора наблюдаться весь...        4
# 2  привет диана системный аналитик экс преподават...        3
# 3  привет хабра связь команда облако следить ново...        0
# 4  развитие информационный технология первый алго...        6

# %%
for i in sorted(df['cluster'].unique()):
    corpus = get_corpus(df[df['cluster'] == i].text_lemm.values)
    procWordCloud = get_wordCloud(corpus)
    
    fig = plt.figure(figsize=(15, 5))
    plt.subplot(1, 2, 1)
    plt.imshow(procWordCloud)
    plt.axis('off')
    plt.title(f'НОМЕР КЛАСТЕРА: {i}')
    plt.subplot(1, 2, 1)

# %%
df_cluster_desc = pd.DataFrame()

# %%
df_cluster_desc['cluster'] = sorted(df['cluster'].unique())

# %%
df_cluster_desc['description'] = ['Развитие', 'Разработки компаний', 'Вклад в развитие', 'Приложения', 'Тайм-менеджемент', "Рабочий код", 'Командный проект', 'Дизайнерское решение']

# %%
df_cluster_desc
# Out:
#    cluster           description
# 0        0              Развитие
# 1        1   Разработки компаний
# 2        2      Вклад в развитие
# 3        3            Приложения
# 4        4      Тайм-менеджемент
# 5        5           Рабочий код
# 6        6      Командный проект
# 7        7  Дизайнерское решение
